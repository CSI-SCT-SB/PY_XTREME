# %% [markdown]
# <a href="https://colab.research.google.com/github/ahadanzar/PY_XTREME/blob/main/Matplotlib/Plane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ahad Anzar
#Program to plot a plane on a 3d plot

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
x, y = np.meshgrid(x, y)
eq = 0.12 * x + 0.01 * y + 1.09
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(x, y, eq)

plt.show()
