# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan-anil/PY_XTREME/blob/a1/Numpy/cuberoot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# cbrt () from numpy

import numpy as np

arr1 = [1, 27000, 64, -1000]
print ("cuberoot value of arr1 : ", np.cbrt(arr1))

arr2 = [99,-128]
print ("\ncube root value of arr2 : ", np.cbrt(arr2))
# Out:
# cuberoot value of arr1 :  [  1.  30.   4. -10.]
#
# cube root value of arr2 :  [ 4.62606501 -5.0396842 ]
