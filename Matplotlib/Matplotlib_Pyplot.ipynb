# %% [markdown]
# <a href="https://colab.research.google.com/github/amithbiju/PY_XTREME/blob/main/Matplotlib/Matplotlib_Pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()
