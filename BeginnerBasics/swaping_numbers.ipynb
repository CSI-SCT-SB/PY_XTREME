# %% [markdown]
# <a href="https://colab.research.google.com/github/anirxudh/PY_XTREME/blob/main/BeginnerBasics/swaping_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ANIRUDH S NAIR
#SWAPPING TWO NUMBERS
a=int(input("ENTER THE FIRST NUMBER: "))
b=int(input("ENTER THE SECOND NUMBER: "))

# create a temporary variable to store the number and then swap it

temp=a
a=b
b=temp

print('The value of a after swapping: {}'.format(a))
print('The value of b after swapping: {}'.format(b))
# Out:
# ENTER THE FIRST NUMBER43
# ENTER THE SECOND NUMBER67
# The value of a after swapping: 67
# The value of b after swapping: 43
