# %% [markdown]
# <a href="https://colab.research.google.com/github/dsg1320/PY_XTREME/blob/main/Pandas/panda_graph%20plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy   as np

import os
import pandas as pd


os.chdir("/content")
cars_data=pd.read_csv('toyota.csv')


plt.scatter(cars_data["Price"],cars_data["Age"])

plt.title("TOYOTA")
plt.xlabel("PRICE")
plt.ylabel("AGE")

plt.show()
