# %% [markdown]
# <a href="https://colab.research.google.com/github/raknasavis703/PY_XTREME/blob/main/turtle/SivaSankar_TurtleIsvisible.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ColabTurtlePlus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import ColabTurtlePlus.Turtle as turtle #import turtle will be used in a normal python compiler
turtle.initializeTurtle() #It is present in ColabTurtle to initialise the turtle
turtle.forward(75)
turtle.hideturtle()
print(turtle.isvisible())#Checks the visibility of arrowhead of turtle,returns True if shown, False if it’s hidden.
turtle.showturtle()
print(turtle.isvisible())
print(turtle.position())
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="475.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90,475.0,300.0) translate(475.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# </g>
#       </svg>
# False
# True
# (75.0, 0.0)
